# %% [markdown]
# ## In this notebook, we will be inspecting data from cancelled subscribers, tidying this data, testing it for automation and later showing our findings.

# %% [markdown]
# ### First, we will carry out the necessary imports and change the working directory.

# %%
import sqlite3    #import SQLite library, which allows interation with SQLite databases
import pandas as pd    #import pandas - a library used for data manipulation
import ast    #imports ast - used for identifying errors within the code  # CHECK THIS HAS BEEN USED
import json
import numpy as np    #import NumPy - used to add useful mathematical functions
import os    #imports os - used to interact with the importating systenm
from datetime import datetime    #imports datetime module allowing better manipulation of dates and times

# %%
os.chdir(r'\Users\maxpe\OneDrive\Documents\Codecademy\Cancelled Subscribers Automated Data Ingestion\subscriber-pipeline-starter-kit\dev') #changes the working directory - the 'r' is used to tell Python to treat the backslashes as characters, rather than an escape character
pd.set_option('display.max_colwidth', None) # pandas may cut out information on a dataframe if there are too many characters, this will override that.

# %% [markdown]
# ### Below, we will establish a connection to the database, and then run a query to find what tables we will be working with.

# %%
con = sqlite3.connect('cademycode.db') #this connects to cademycode.db
cur = con.cursor() #this creates a cursor object - which will allow us to manipulate the data with Python
#the below query creates an empty list, as the loop iterates through the database, each time it finds a table, it will add it to the list, and then print it out, allowing us to see what tables are in the database
table_list = []
for row in cur.execute("SELECT name FROM sqlite_master WHERE type = 'table'"):
    table_list.append(row[0])
print(table_list)
# Out:
# ['cademycode_students', 'cademycode_courses', 'cademycode_student_jobs', 'cademycode_cleaned', 'cademycode_cleaned.db']

# %% [markdown]
# ### Now we know the tables, we can save these as Python variables to enable maniuplation

# %%
# the next 3 queries takes all the rows from the tables in the table_list output, and loads them into dataframes using pandas.
students = pd.read_sql_query("SELECT * FROM cademycode_students", con)
courses = pd.read_sql_query("SELECT * FROM cademycode_courses", con)
student_jobs = pd.read_sql_query("SELECT * FROM cademycode_student_jobs", con)

# these print statement show the number of rows of data within each dataframe
print('students:', len(students))
print('courses:', len(courses))
print('student_jobs:', len(student_jobs))
# Out:
# students: 5000
# courses: 10
# student_jobs: 13

# %% [markdown]
# ### We now have each table as a dataframe, it is time to inspect these tables, and look for data anomolies.

# %%
# We will start with the students table, first, we will call .head(), this will show the first 5 rows of the data, allowing us to get a sense of the table.
students.head()
# Out:
#    uuid             name         dob sex  \
# 0     1  Annabelle Avery  1943-07-03   F
# 1     2      Micah Rubio  1991-02-07   M
# 2     3       Hosea Dale  1989-12-07   M
# 3     4     Mariann Kirk  1988-07-31   F
# 4     5  Lucio Alexander  1963-08-31   M
#
#                                                                                                       contact_info  \
# 0   {"mailing_address": "303 N Timber Key, Irondale, Wisconsin, 84736", "email": "annabelle_avery9376@woohoo.com"}
# 1                 {"mailing_address": "767 Crescent Fair, Shoals, Indiana, 37439", "email": "rubio6772@hmail.com"}
# 2  {"mailing_address": "P.O. Box 41269, St. Bonaventure, Virginia, 83637", "email": "hosea_dale8084@coldmail.com"}
# 3             {"mailing_address": "517 SE Wintergreen Isle, Lane, Arkansas, 82242", "email": "kirk4005@hmail.com"}
# 4  {"mailing_address": "18 Cinder Cliff, Doyles borough, Rhode Island, 73737", "email": "alexander9810@hmail.com"}
#
#   job_id num_course_taken current_career_path_id time_spent_hrs
# 0    7.0              6.0                    1.0           4.99
# 1    7.0              5.0                    8.0            4.4
# 2    7.0              8.0                    8.0           6.74
# 3    6.0              7.0                    9.0          12.31
# 4    7.0             14.0                    3.0           5.64

# %%
students.info()
# calling .info() will give us details of the column names, the count and the datatype.
# we can see tables 5,6,7,8 have some missing values.
# we see some datatypes arent correct, dob should be date time, time_spent_hrs, current_career_path_id, num_course_taken and job_id should also be updated to floats / integers
# contact_info also needs breaking up into separate columns for each part of the address and email address.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    5000 non-null   int64
#  1   name                    5000 non-null   object
#  2   dob                     5000 non-null   object
#  3   sex                     5000 non-null   object
#  4   contact_info            5000 non-null   object
#  5   job_id                  4995 non-null   object
#  6   num_course_taken        4749 non-null   object
#  7   current_career_path_id  4529 non-null   object
#  8   time_spent_hrs          4529 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 351.7+ KB

# %%
# this selects the 'dob' column from students, and converts this to a data time format with pandas
students['dob'] = pd.to_datetime(students['dob'])  # Convert dob to datetime

# This creates an 'age' column, and assigns the students age by acquiring the current date.
# After current date is acquired, it finds the days passed since the students dob and divides this by 365, to find the year.
students['age'] = (datetime.now() - students['dob']).dt.days // 365

# call .head() to confirm the new age column
students.head()
# Out:
#    uuid             name        dob sex  \
# 0     1  Annabelle Avery 1943-07-03   F
# 1     2      Micah Rubio 1991-02-07   M
# 2     3       Hosea Dale 1989-12-07   M
# 3     4     Mariann Kirk 1988-07-31   F
# 4     5  Lucio Alexander 1963-08-31   M
#
#                                                                                                       contact_info  \
# 0   {"mailing_address": "303 N Timber Key, Irondale, Wisconsin, 84736", "email": "annabelle_avery9376@woohoo.com"}
# 1                 {"mailing_address": "767 Crescent Fair, Shoals, Indiana, 37439", "email": "rubio6772@hmail.com"}
# 2  {"mailing_address": "P.O. Box 41269, St. Bonaventure, Virginia, 83637", "email": "hosea_dale8084@coldmail.com"}
# 3             {"mailing_address": "517 SE Wintergreen Isle, Lane, Arkansas, 82242", "email": "kirk4005@hmail.com"}
# 4  {"mailing_address": "18 Cinder Cliff, Doyles borough, Rhode Island, 73737", "email": "alexander9810@hmail.com"}
#
#   job_id num_course_taken current_career_path_id time_spent_hrs  age
# 0    7.0              6.0                    1.0           4.99   81
# 1    7.0              5.0                    8.0            4.4   33
# 2    7.0              8.0                    8.0           6.74   34
# 3    6.0              7.0                    9.0          12.31   36
# 4    7.0             14.0                    3.0           5.64   61

# %%
# We will remove contact_info, and replace it with columns 'street' 'city' 'state' 'post_code' and 'email'
# The data is stored as JSON, so we use the json module and convert the JSON into a dictionary, allowing us to work with it

def parse_contact_info(info):
    # This converts the JSON string to a Python dictionary
    parsed_info = json.loads(info)  
    mailing_address = parsed_info['mailing_address']
    
    # This will split the key 'mailing_address' into 4 variables, using the comma as a separator
    address_parts = mailing_address.split(', ')
    if len(address_parts) == 4:
        street = address_parts[0]
        city = address_parts[1]
        state = address_parts[2]
        post_code = address_parts[3]

    # The email key does not need separating so it is easier to work with
    email = parsed_info['email']
    
    return pd.Series([street, city, state, post_code, email])

students[['street', 'city', 'state', 'post_code', 'email']] = students['contact_info'].apply(parse_contact_info)

# finally, we remove the contact_info column
students.drop(columns=['contact_info'], inplace=True)

# %%
# checking the new fields have been added
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    5000 non-null   int64
#  1   name                    5000 non-null   object
#  2   dob                     5000 non-null   datetime64[ns]
#  3   sex                     5000 non-null   object
#  4   job_id                  4995 non-null   object
#  5   num_course_taken        4749 non-null   object
#  6   current_career_path_id  4529 non-null   object
#  7   time_spent_hrs          4529 non-null   object
#  8   age                     5000 non-null   int64
#  9   street                  5000 non-null   object
#  10  city                    5000 non-null   object
#  11  state                   5000 non-null   object
#  12  post_code               5000 non-null   object
#  13  email                   5000 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(11)
# memory usage: 547.0+ KB

# %%
# Now, we change the data types of certain columns to floats
students['job_id'] = students['job_id'].astype(float)
students['num_course_taken'] = students['num_course_taken'].astype(float)
students['current_career_path_id'] = students['current_career_path_id'].astype(float)
students['time_spent_hrs'] = students['time_spent_hrs'].astype(float)

# %%
# Checking data types have updated
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    5000 non-null   int64
#  1   name                    5000 non-null   object
#  2   dob                     5000 non-null   datetime64[ns]
#  3   sex                     5000 non-null   object
#  4   job_id                  4995 non-null   float64
#  5   num_course_taken        4749 non-null   float64
#  6   current_career_path_id  4529 non-null   float64
#  7   time_spent_hrs          4529 non-null   float64
#  8   age                     5000 non-null   int64
#  9   street                  5000 non-null   object
#  10  city                    5000 non-null   object
#  11  state                   5000 non-null   object
#  12  post_code               5000 non-null   object
#  13  email                   5000 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 547.0+ KB

# %%
# Checking for duplicates; all fields return false, indicating no duplicated data
students.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Length: 5000, dtype: bool

# %%
# We will now look into the missing values in job_id
missing_job_id = students[students['job_id'].isnull()]
missing_job_id
# Out:
#       uuid              name        dob sex  job_id  num_course_taken  \
# 162    163        Glen Riley 2002-08-22   M     NaN               8.0
# 757    758  Mercedez Vorberg 2002-03-25   F     NaN              15.0
# 854    855           Kurt Ho 2002-05-29   M     NaN               0.0
# 1029  1030      Penny Gaines 2002-03-01   N     NaN              15.0
# 1542  1543  Frederick Reilly 2002-11-13   M     NaN               7.0
#
#       current_career_path_id  time_spent_hrs  age             street  \
# 162                      3.0            5.70   22     P.O. Box 37267
# 757                      4.0            4.14   22  284 Cedar Seventh
# 854                      8.0           23.72   22     P.O. Box 27254
# 1029                     4.0           16.25   22     138 Misty Vale
# 1542                     9.0           21.32   21     P.O. Box 40769
#
#                   city          state post_code  \
# 162    Cornlea village      Tennessee     19192
# 757     Virden village     Washington     60489
# 854               Olin  New Hampshire     60067
# 1029  Stockton borough  West Virginia     53630
# 1542     Quakervillage       Maryland     96218
#
#                                 email
# 162          glen_riley4484@hmail.com
# 757           mercedez6297@woohoo.com
# 854                 ho6107@inlook.com
# 1029             gaines2897@hmail.com
# 1542  frederick_reilly6971@woohoo.com

# %%
# There are no obvious correlations as to why these are missing, due to only 5 rows from 1,000 being missing,
# We will delete the missing values, as this should not impact our dataset.
students = students.dropna(subset=['job_id'])
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4995 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    4995 non-null   int64
#  1   name                    4995 non-null   object
#  2   dob                     4995 non-null   datetime64[ns]
#  3   sex                     4995 non-null   object
#  4   job_id                  4995 non-null   float64
#  5   num_course_taken        4744 non-null   float64
#  6   current_career_path_id  4524 non-null   float64
#  7   time_spent_hrs          4524 non-null   float64
#  8   age                     4995 non-null   int64
#  9   street                  4995 non-null   object
#  10  city                    4995 non-null   object
#  11  state                   4995 non-null   object
#  12  post_code               4995 non-null   object
#  13  email                   4995 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 585.4+ KB

# %%
# This will show the first 50 records where num_course_taken is null
missing_num_course_taken = students[students['num_course_taken'].isnull()]
missing_num_course_taken.head(50)
# Out:
#      uuid                name        dob sex  job_id  num_course_taken  \
# 25     26       Doug Browning 1970-06-08   M     7.0               NaN
# 26     27     Damon Schrauwen 1953-10-31   M     4.0               NaN
# 51     52          Alisa Neil 1977-05-28   F     5.0               NaN
# 70     71     Chauncey Hooper 1962-04-07   M     3.0               NaN
# 80     81     Ellyn van Heest 1984-06-28   F     3.0               NaN
# 96     97       Moises Krekel 2004-06-15   M     8.0               NaN
# 139   140    Charlie Semvoort 2004-03-06   N     8.0               NaN
# 149   150     Lindsey Mcclain 1972-11-30   N     6.0               NaN
# 157   158      Ching Rijkensz 1988-02-17   N     3.0               NaN
# 202   203       Bettie Torres 1973-06-05   N     6.0               NaN
# 209   210      Clyde Benskoop 1989-06-23   M     7.0               NaN
# 224   225         Bettina Fry 1971-01-12   F     2.0               NaN
# 231   232   Cecil Blankenship 2001-11-18   M     4.0               NaN
# 252   253  Lenore Ferdinandus 1988-11-30   N     1.0               NaN
# 258   259       Shizuko Singh 1973-04-02   F     5.0               NaN
# 281   282   Christinia Meyers 1973-03-06   F     4.0               NaN
# 286   287       Madlyn Castro 1944-08-26   N     4.0               NaN
# 296   297        Archie Komen 1973-03-27   M     6.0               NaN
# 318   319        Hilde Mclean 1992-01-27   F     3.0               NaN
# 332   333      Lauralee Crane 1989-11-27   F     5.0               NaN
# 333   334         Elida Bruce 1962-03-03   F     5.0               NaN
# 343   344        Titus Gaines 1989-01-30   M     6.0               NaN
# 354   355          Vanda Goff 1958-07-08   F     1.0               NaN
# 389   390      Kathryne Matse 1959-07-08   F     6.0               NaN
# 401   402        Scotty Wiley 1975-03-16   M     7.0               NaN
# 414   415      Sherie Roberts 1942-12-29   F     2.0               NaN
# 440   441         Neomi Hayes 1944-11-07   F     6.0               NaN
# 490   491         Adah Keiman 1942-03-27   F     6.0               NaN
# 491   492       Shayne Hardin 1945-09-05   M     4.0               NaN
# 499   500    Wilda van Linden 1967-11-02   F     2.0               NaN
# 501   502       Jamila Golden 1959-10-08   F     1.0               NaN
# 513   514        Eula Lindsay 1960-06-01   N     3.0               NaN
# 520   521         Will Heuvel 1973-06-18   M     6.0               NaN
# 529   530        Harvey Myers 1948-11-19   M     5.0               NaN
# 543   544  Sherwood van Welij 1946-12-28   M     2.0               NaN
# 549   550  Scottie van Imbyze 1985-10-17   M     4.0               NaN
# 588   589      Lenny Arellano 1965-02-03   M     6.0               NaN
# 601   602  Florencio de Bruin 1977-04-17   M     7.0               NaN
# 602   603       Kellie Golden 1974-09-20   F     1.0               NaN
# 604   605       Chantay James 1950-12-21   F     3.0               NaN
# 662   663         Beau Murphy 1992-11-19   N     7.0               NaN
# 529             harvey1051@woohoo.com
# 543         sherwood8992@coldmail.com
# 549  scottie_vanimbyze2936@inlook.com
# 588           arellano8558@inlook.com
# 601          florencio1371@inlook.com
# 602       kellie_golden3127@hmail.com
# 604       chantay_james2476@hmail.com
# 662        beau_murphy3561@inlook.com
# 668               tana4262@woohoo.com
# 689            cherrie2492@woohoo.com
# 725   jesus_washington5197@inlook.com
# 786             higgins8490@hmail.com
# 808                 gay5705@hmail.com
# 901              treasa8720@hmail.com
# 923   kaitlin_schutter5451@inlook.com
# 933           garfield8997@woohoo.com
# 937                cary815@woohoo.com

# %%
# After investigating the missing data for num_course_taken, we can not see any correlations with the other columns as to why this is
# Due to us having no access to a data team, or data entry team, we cannot investigate how the data is being added
# Due to the data being approximately 5% of the set, we will remove this to allow for more accurate analysis on the remaining set
students = students.dropna(subset=['num_course_taken'])
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4744 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    4744 non-null   int64
#  1   name                    4744 non-null   object
#  2   dob                     4744 non-null   datetime64[ns]
#  3   sex                     4744 non-null   object
#  4   job_id                  4744 non-null   float64
#  5   num_course_taken        4744 non-null   float64
#  6   current_career_path_id  4293 non-null   float64
#  7   time_spent_hrs          4293 non-null   float64
#  8   age                     4744 non-null   int64
#  9   street                  4744 non-null   object
#  10  city                    4744 non-null   object
#  11  state                   4744 non-null   object
#  12  post_code               4744 non-null   object
#  13  email                   4744 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 555.9+ KB

# %%
# This will show the first 50 records where current_career_path_id is null
missing_current_career_path_id = students[students['current_career_path_id'].isnull()]
missing_current_career_path_id.head(50)
# Out:
#      uuid                   name        dob sex  job_id  num_course_taken  \
# 15     16          Norene Dalton 1976-04-30   F     6.0               0.0
# 19     20  Sofia van Steenbergen 1990-02-21   N     7.0              13.0
# 30     31      Christoper Warner 1989-12-28   M     2.0               5.0
# 49     50           Antony Horne 1996-05-29   M     3.0               2.0
# 54     55              Omar Bunk 1955-11-08   M     3.0              14.0
# 55     56        Lincoln Hartman 1950-07-15   M     5.0               8.0
# 62     63           Zana Willems 1953-11-23   F     2.0               2.0
# 64     65            Jasmine Vos 1942-08-24   F     5.0              13.0
# 71     72         Genevie Huerta 1954-11-15   F     1.0               8.0
# 88     89          Scott de Boef 1976-01-21   M     2.0              11.0
# 120   121            Odilia Pael 1957-01-27   F     1.0              12.0
# 143   144        Marilou de Jong 2004-10-31   F     8.0              13.0
# 145   146          Hilton Guzman 1992-07-20   N     6.0               7.0
# 159   160   Sachiko van der Bilt 1969-06-20   F     3.0               4.0
# 177   178           Burl Edwards 1968-10-15   M     3.0               1.0
# 208   209             Alan Roman 1988-08-12   M     6.0               1.0
# 214   215       Cristobal Zeeman 1961-05-04   M     7.0              15.0
# 232   233          Rafael de Rek 1987-07-31   M     2.0              12.0
# 248   249       Christin Cordova 1991-10-27   N     7.0              13.0
# 271   272         Melisa Baldwin 1945-03-10   F     6.0              13.0
# 278   279         Hyacinth Mejia 1996-04-28   F     7.0               6.0
# 319   320            Mose Barlow 1950-08-21   M     4.0               1.0
# 321   322           Mikaela Goes 1976-08-07   F     6.0               3.0
# 330   331            Ching Glenn 1943-09-30   N     3.0               3.0
# 353   354          Loraine Mentz 1976-02-17   F     6.0              12.0
# 382   383          Lonny Hensley 1994-11-14   M     2.0              15.0
# 388   389        Lavone Lawrence 1954-06-09   F     2.0               9.0
# 400   401       Tracee Versteegh 1983-12-24   F     5.0               9.0
# 410   411       Harrison Schmitt 1996-01-17   M     6.0               5.0
# 488   489     Raleigh van Malsem 1961-11-12   M     7.0               2.0
# 494   495              Eloy Mann 1942-04-07   N     2.0               2.0
# 506   507        Lekisha Kerkhof 1979-05-01   N     6.0               5.0
# 515   516    Florinda Groeneveld 1992-06-29   F     1.0              15.0
# 521   522         Fidelia Bieren 1984-06-24   F     6.0               8.0
# 530   531        Nicholas Crosby 1971-01-20   M     6.0              13.0
# 537   538          Delana Kaiser 1962-02-01   F     2.0               8.0
# 540   541  Tristan van der Greff 1952-09-11   M     4.0              13.0
# 551   552    Donte van der Woude 1963-06-05   M     2.0               9.0
# 552   553           Steve Arisdr 1943-03-13   M     4.0              11.0
# 567   568          Gaylord Watts 1996-05-27   M     5.0               1.0
# 570   571          Leanna Cortez 1944-03-01   F     6.0               1.0
# 575   576    Corrina van der Ham 1979-01-05   F     5.0               5.0
# 584   585           Ouida Dalton 1989-05-25   F     3.0               7.0
# 587   588          Anjelica Soto 1967-11-28   F     2.0               4.0
# 600   601           Candyce Kane 1973-01-11   N     6.0               1.0
# 622   623           Garret Cooll 1966-08-04   M     4.0               1.0
# 624   625      Augustus Cummings 1942-05-02   M     2.0               0.0
# 640   641     Slyvia Fitzpatrick 1975-09-13   N     6.0               5.0
# 661   662         Brigitte Gould 1989-01-25   F     4.0              10.0
# 670   671       Marlys Cervantes 1962-01-17   F     5.0              11.0
#
#      current_career_path_id  time_spent_hrs  age                       street  \
# 15                      NaN             NaN   48            130 Wishing Essex
# 19                      NaN             NaN   34          634 Clear Barn Dell
# 30                      NaN             NaN   34          556 Stony Highlands
# 49                      NaN             NaN   28               P.O. Box 78685
# 54                      NaN             NaN   69              445 Dale Hollow
# 55                      NaN             NaN   74               P.O. Box 22581
# 62                      NaN             NaN   70            319 Iron Treasure
# 64                      NaN             NaN   82               P.O. Box 56722
# 71                      NaN             NaN   70            401 Quaking Smith
# 88                      NaN             NaN   48               P.O. Box 47591
# 120                     NaN             NaN   67      131 Silver Beacon Woods
# 143                     NaN             NaN   20                141 SE Corner
# 145                     NaN             NaN   32               P.O. Box 32682
# 159                     NaN             NaN   55          219 Broad Club Ramp
# 177                     NaN             NaN   56            869 River Freeway
# 208                     NaN             NaN   36                358 Maple Way
# 214                     NaN             NaN   63         128 Fallen Panda Key
# 232                     NaN             NaN   37              413 Tawny Route
# 248                     NaN             NaN   33          404 Pleasant Island
# 271                     NaN             NaN   79          128 Colonial Parade
# 278                     NaN             NaN   28         693 Clear Summit Dam
# 319                     NaN             NaN   74                14 Honey Land
# 321                     NaN             NaN   48                523 View Mews
# 330                     NaN             NaN   81               P.O. Box 47384
# 353                     NaN             NaN   48          607 Dewy Park Jetty
# 382                     NaN             NaN   29             880 Green Corner
# 388                     NaN             NaN   70            752 Golden Parade
# 400                     NaN             NaN   40                332 Old Shore
# 410                     NaN             NaN   28         813 Butterfly Meadow
# 488                     NaN             NaN   63               88 Tawny Sixth
# 494                     NaN             NaN   82              791 Broad Acres
# 506                     NaN             NaN   45             350 Cliff Arcade
# 515                     NaN             NaN   32                 434 SW Manor
# 521                     NaN             NaN   40   138 Heather Nectar Station
# 530                     NaN             NaN   53                817 Broad Elk
# 537                     NaN             NaN   62            769 First Terrace
# 540                     NaN             NaN   72               P.O. Box 72903
# 551                     NaN             NaN   61               71 Cliff Vista
# 552                     NaN             NaN   81        641 Fallen Island Way
# 567                     NaN             NaN   28      589 Easy Butterfly Quay
# 570                     NaN             NaN   80               P.O. Box 82835
# 575                     NaN             NaN   45  481 Golden Course Stravenue
# 584                     NaN             NaN   35         33 Broad Rest Square
# 587                     NaN             NaN   56               985 Squaw Walk
# 600                     NaN             NaN   51    958 Broad Forest Causeway
# 622                     NaN             NaN   58               955 Quiet Spur
# 624                     NaN             NaN   82             599 Amber Willow
# 640                     NaN             NaN   49                35 First Isle
# 661                     NaN             NaN   35             244 Blue Station
# 670                     NaN             NaN   62            94 Cliff Junction
#
#                     city           state post_code  \
# 15                Branch            Ohio     13616
# 19                Beaman         Georgia     33288
# 30                 Drain        Illinois     01973
# 49                 Lenox           Texas     15516
# 54       Vermont village  South Carolina     28329
# 55     Southmont borough   West Virginia     03735
# 62            Thermalito        Virginia     15241
# 64               La Veta         Vermont     72685
# 71             McDermitt         Montana     96073
# 88     Pemberton borough    Pennsylvania     13428
# 120               Atkins         Vermont     18597
# 143         Chapmanville      New Jersey     07630
# 145   Fall River village          Hawaii     35048
# 159            McRoberts          Alaska     16251
# 177             Coyville        Nebraska     49861
# 208           Lake Purdy        Arkansas     51336
# 214           Scottsboro           Idaho     41506
# 232              Gosnell            Ohio     52323
# 248             Sycamore         Wyoming     62144
# 271               Grubbs      New Jersey     84053
# 278          Irondequoit        Oklahoma     25590
# 319      San Luis Obispo   West Virginia     69370
# 321             Blanding        Colorado     53072
# 330                Luana        Kentucky     50425
# 353               Masury    South Dakota     66332
# 382                Wasco   New Hampshire     23235
# 388  Lake Placid village           Maine     05041
# 400            Fortescue        Kentucky     96640
# 410             Douglass       Wisconsin     72159
# 488   Woodsfield village          Nevada     25643
# 494            Menominee      New Mexico     25479
# 506   Glen Ellyn village         Wyoming     97257
# 515              Downing         Indiana     04340
# 521                 Peru   New Hampshire     35010
# 530       Roseburg North           Texas     28765
# 537    Weissport borough  South Carolina     80532
# 540                Gabbs       Tennessee     85285
# 551      Fairmontvillage        Colorado     63311
# 552               Welton        New York     08124
# 567               Larose         Georgia     65381
# 570              Hornell    North Dakota     89463
# 575    Chickasaw village            Iowa     47201
# 584       Lowry Crossing          Oregon     19453
# 587          Rogue River        Arkansas     28295
# 600            Troutdale         Arizona     99876
# 622           Cottonport       Tennessee     05356
# 624               Makaha         Indiana     00504
# 640        Weeping Water        Virginia     43595
# 661   Stillwater borough         Vermont     33103
# 670       Jenkin borough          Nevada     05407
#
#                                 email
# 15        norene_dalton9509@hmail.com
# 19      vansteenbergen8482@inlook.com
# 30            warner5906@coldmail.com
# 49             antony577@coldmail.com
# 54              omar1245@coldmail.com
# 55              hartman6763@hmail.com
# 62             willems4043@woohoo.com
# 64               vos8677@coldmail.com
# 71      genevie_huerta5604@inlook.com
# 88      scott_deboef9061@coldmail.com
# 120               pael2238@woohoo.com
# 143             dejong3230@inlook.com
# 145              hilton9033@hmail.com
# 159  sachiko_vanderbilt1816@hmail.com
# 177              edwards851@hmail.com
# 208              roman6240@inlook.com
# 214             zeeman3742@inlook.com
# 232        rafael_derek3619@hmail.com
# 248    christin_cordova5844@hmail.com
# 271     melisa_baldwin3025@inlook.com
# 278            hyacinth2994@hmail.com
# 319              barlow1485@hmail.com
# 321             mikaela7146@hmail.com
# 330               glenn3572@hmail.com
# 353              mentz5518@inlook.com
# 382             hensley6113@hmail.com
# 388           lawrence4637@inlook.com
# 400   tracee_versteegh9596@woohoo.com
# 410     harrison_schmitt17@woohoo.com
# 488           vanmalsem1452@hmail.com
# 494                mann7868@hmail.com
# 506    lekisha_kerkhof5248@woohoo.com
# 515            florinda1102@hmail.com
# 521             bieren2010@woohoo.com
# 530           nicholas8155@woohoo.com
# 537    delana_kaiser4464@coldmail.com
# 540          tristan1307@coldmail.com
# 551            donte7211@coldmail.com
# 552              arisdr149@inlook.com
# 567            watts9140@coldmail.com
# 570      leanna_cortez6187@inlook.com
# 575   corrina_vanderham1086@hmail.com
# 584               ouida1276@hmail.com
# 587           anjelica5533@woohoo.com
# 600               kane3383@woohoo.com
# 622        garret_cooll6585@hmail.com
# 624           cummings2093@woohoo.com
# 640        fitzpatrick8024@woohoo.com
# 661            brigitte7660@hmail.com
# 670             marlys7217@inlook.com

# %%
# Looking at the data above, it is obvious to see that when a student is not enrolled on a current career path, there are no respective hours spent.
# To maintain the dataset, we will fill the NaN's with a 0 for both columns as we have already deleted approximately 5% of data.
students['current_career_path_id'].fillna(0, inplace=True)
students['time_spent_hrs'].fillna(0, inplace=True)
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4744 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    4744 non-null   int64
#  1   name                    4744 non-null   object
#  2   dob                     4744 non-null   datetime64[ns]
#  3   sex                     4744 non-null   object
#  4   job_id                  4744 non-null   float64
#  5   num_course_taken        4744 non-null   float64
#  6   current_career_path_id  4744 non-null   float64
#  7   time_spent_hrs          4744 non-null   float64
#  8   age                     4744 non-null   int64
#  9   street                  4744 non-null   object
#  10  city                    4744 non-null   object
#  11  state                   4744 non-null   object
#  12  post_code               4744 non-null   object
#  13  email                   4744 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 555.9+ KB

# %%
# And now, the courses dataframe:
# Due to the students who werent on career path, which we replaced NaN's with 0's, we will create a career path of 'Not Applicable'
# This placeholder will help the data integrity during the merge
not_applicable = {
    'career_path_id': 0,
    'career_path_name': 'Not Applicable',
    'hours_to_complete': 0
}
not_applicable_df = pd.DataFrame([not_applicable])  # This converts the above dictionary into a dataframe which allows pd.concat to merge courses with not_applicable
courses = pd.concat([courses, not_applicable_df], ignore_index=True)
courses.head(50)
# Out:
#     career_path_id           career_path_name  hours_to_complete
# 0                1             data scientist                 20
# 1                2              data engineer                 20
# 2                3               data analyst                 12
# 3                4       software engineering                 25
# 4                5           backend engineer                 18
# 5                6          frontend engineer                 20
# 6                7              iOS developer                 27
# 7                8          android developer                 27
# 8                9  machine learning engineer                 35
# 9               10             ux/ui designer                 15
# 10               0             Not Applicable                  0

# %%
courses.info()
# Again, everything looks as it should below.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   career_path_id     11 non-null     int64
#  1   career_path_name   11 non-null     object
#  2   hours_to_complete  11 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 396.0+ bytes

# %%
# Finally, the student_jobs dataframe:
student_jobs.head(50)
# Out:
#     job_id        job_category  avg_salary
# 0        1           analytics       86000
# 1        2            engineer      101000
# 2        3  software developer      110000
# 3        4            creative       66000
# 4        5  financial services      135000
# 5        6           education       61000
# 6        7                  HR       80000
# 7        8             student       10000
# 8        9          healthcare      120000
# 9        0               other       80000
# 10       3  software developer      110000
# 11       4            creative       66000
# 12       5  financial services      135000

# %%
student_jobs = student_jobs.drop_duplicates()
# There are a couple of duplicates which we have cleared up

# %%
student_jobs.info()
# Below, these look fine, which cleans up the 3 dataframes!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_id        10 non-null     int64
#  1   job_category  10 non-null     object
#  2   avg_salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 320.0+ bytes

# %%
students.info()
courses.info()
student_jobs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4744 entries, 0 to 4999
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    4744 non-null   int64
#  1   name                    4744 non-null   object
#  2   dob                     4744 non-null   datetime64[ns]
#  3   sex                     4744 non-null   object
#  4   job_id                  4744 non-null   float64
#  5   num_course_taken        4744 non-null   float64
#  6   current_career_path_id  4744 non-null   float64
#  7   time_spent_hrs          4744 non-null   float64
#  8   age                     4744 non-null   int64
#  9   street                  4744 non-null   object
#  10  city                    4744 non-null   object
#  11  state                   4744 non-null   object
#  12  post_code               4744 non-null   object
#  13  email                   4744 non-null   object
# dtypes: datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 555.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   career_path_id     11 non-null     int64
#  1   career_path_name   11 non-null     object
#  2   hours_to_complete  11 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 396.0+ bytes
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   job_id        10 non-null     int64
#  1   job_category  10 non-null     object
#  2   avg_salary    10 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 320.0+ bytes

# %% [markdown]
# ### We now have the dataframes cleaned, we will now merge them into one, export into a database and then create a CSV

# %%
# First, we will merge students with student_jobs
# We will join all tables on job_id, as this field is present in each table
# We will use left joins to keep flexibility and ensure all records are kept
# On the final merge, we use left_on and right_on to link the student_jobs_merged and courses on current_career_path_id and career_path_id
final_df = students.merge(courses, left_on='current_career_path_id', right_on='career_path_id', how='left')
final_df = final_df.merge(student_jobs, on='job_id', how='left')
final_df.head(50)
# Out:
#     uuid                   name        dob sex  job_id  num_course_taken  \
# 0      1        Annabelle Avery 1943-07-03   F     7.0               6.0
# 1      2            Micah Rubio 1991-02-07   M     7.0               5.0
# 2      3             Hosea Dale 1989-12-07   M     7.0               8.0
# 3      4           Mariann Kirk 1988-07-31   F     6.0               7.0
# 4      5        Lucio Alexander 1963-08-31   M     7.0              14.0
# 5      6       Shavonda Mcmahon 1989-10-15   F     6.0              10.0
# 6      7    Terrell Bleijenberg 1959-05-05   M     2.0               9.0
# 7      8         Stanford Allan 1997-11-22   M     3.0               3.0
# 8      9        Tricia Delacruz 1961-10-20   F     1.0               6.0
# 9     10   Regenia van der Helm 1999-02-23   N     5.0               7.0
# 10    11       Shonda Stephanin 1998-10-24   F     7.0               5.0
# 29    Closter borough         Montana     06529
# 30            Bonsall         Vermont     93588
# 31         Horse Cave           Idaho     68425
# 32      Crystal Lakes        New York     38056
# 33     Bonner Springs        Nebraska     76506
# 34           Montreal         Georgia     62218
# 35      North Madison        Colorado     24053
# 36          Topsfield         Montana     60773
# 37      North Edwards         Vermont     60792
# 38             Mullin      California     34730
# 39         Minnetonka           Texas     54117
# 40            Moclips         Arizona     43700
# 41  Sunny Isles Beach           Texas     67082
# 42      Marion Center           Maine     17322
# 43       South Venice        Virginia     40051
# 44             Medora        Arkansas     01123
# 45      Boulder Flats        Arkansas     01797
# 46         Ropesville  North Carolina     94231
# 47              Lenox           Texas     15516
# 48       Moline Acres         Florida     75485
# 49    Haworth borough        Oklahoma     66701
#
#                                   email  career_path_id  \
# 0        annabelle_avery9376@woohoo.com               1
# 1                   rubio6772@hmail.com               8
# 2           hosea_dale8084@coldmail.com               8
# 3                    kirk4005@hmail.com               9
# 4               alexander9810@hmail.com               3
# 5             shavonda5863@coldmail.com               3
# 6              bleijenberg188@hmail.com               8
# 7       stanford_allan8055@coldmail.com               1
# 8        tricia_delacruz6622@woohoo.com               9
# 9                regenia6908@inlook.com               6
# 10    shonda_stephanin4439@coldmail.com              10
# 11             mcfarland1396@woohoo.com               6
# 12               edwardo8281@inlook.com               5
# 13         robena_padilla1477@hmail.com               9
# 14                tamala4408@woohoo.com               1
# 15          norene_dalton9509@hmail.com               0
# 16                  maris5817@hmail.com               4
# 17               vanhees6330@woohoo.com               9
# 18              werner3867@coldmail.com               8
# 19        vansteenbergen8482@inlook.com               0
# 20            villarreal2146@woohoo.com               3
# 21                  lamb2933@woohoo.com               6
# 22              isabel9601@coldmail.com               5
# 23           eartha_weeks7248@hmail.com               1
# 24        eloy_limmink6109@coldmail.com               3
# 25                rowland6740@hmail.com               3
# 26               edgardo9341@woohoo.com               5
# 27  bettyann_klarenbos7887@coldmail.com               9
# 28              warner5906@coldmail.com               0
# 29       antwan_villegas3074@woohoo.com               3
# 30              madelene9077@inlook.com               7
# 31         dion_donaldson674@inlook.com               4
# 32                  moss3407@inlook.com               3
# 33               natalie2200@inlook.com               2
# 34             leblanc1665@coldmail.com               9
# 35             cristobal6144@woohoo.com              10
# 36               darvill7852@inlook.com               5
# 37                 battle774@inlook.com               6
# 38  latisha_wermeskerken7346@inlook.com               9
# 39              adenrock1157@inlook.com               7
# 40          lula_sanchez1712@inlook.com               6
# 41         cori_castillo5326@woohoo.com               8
# 42               vandeijl2146@hmail.com               5
# 43                 janett1893@hmail.com               3
# 44     malcom_vandervoort4818@hmail.com               6
# 45               vanselm1682@inlook.com               3
# 46             adan_claes2609@hmail.com               6
# 47               antony577@coldmail.com               0
# 48               valorie9955@woohoo.com               1
# 49             ted_groot7898@woohoo.com               4
#
#              career_path_name  hours_to_complete        job_category  \
# 0              data scientist                 20                  HR
# 1           android developer                 27                  HR
# 2           android developer                 27                  HR
# 3   machine learning engineer                 35           education
# 4                data analyst                 12                  HR
# 5                data analyst                 12           education
# 6           android developer                 27            engineer
# 7              data scientist                 20  software developer
# 8   machine learning engineer                 35           analytics
# 9           frontend engineer                 20  financial services
# 10             ux/ui designer                 15                  HR
# 11          frontend engineer                 20                  HR
# 12           backend engineer                 18            engineer
# 13  machine learning engineer                 35  software developer
# 14             data scientist                 20                  HR
# 15             Not Applicable                  0           education
# 16       software engineering                 25  financial services
# 17  machine learning engineer                 35                  HR
# 18          android developer                 27  financial services
# 19             Not Applicable                  0                  HR
# 20               data analyst                 12            creative
# 21          frontend engineer                 20            engineer
# 22           backend engineer                 18           education
# 23             data scientist                 20                  HR
# 24               data analyst                 12  software developer
# 25               data analyst                 12            creative
# 26           backend engineer                 18                  HR
# 27  machine learning engineer                 35           analytics
# 28             Not Applicable                  0            engineer
# 29               data analyst                 12                  HR
# 30              iOS developer                 27           education
# 31       software engineering                 25  software developer
# 32               data analyst                 12  software developer
# 33              data engineer                 20           education
# 34  machine learning engineer                 35            engineer
# 35             ux/ui designer                 15            creative
# 36           backend engineer                 18           education
# 37          frontend engineer                 20            engineer
# 38  machine learning engineer                 35           analytics
# 39              iOS developer                 27                  HR
# 40          frontend engineer                 20            creative
# 41          android developer                 27           analytics
# 42           backend engineer                 18                  HR
# 43               data analyst                 12            engineer
# 44          frontend engineer                 20            creative
# 45               data analyst                 12            engineer
# 46          frontend engineer                 20            engineer
# 47             Not Applicable                  0  software developer
# 48             data scientist                 20           analytics
# 49       software engineering                 25            engineer
#
#     avg_salary
# 0        80000
# 1        80000
# 2        80000
# 3        61000
# 4        80000
# 5        61000
# 6       101000
# 7       110000
# 8        86000
# 9       135000
# 10       80000
# 11       80000
# 12      101000
# 13      110000
# 14       80000
# 15       61000
# 16      135000
# 17       80000
# 18      135000
# 19       80000
# 20       66000
# 21      101000
# 22       61000
# 23       80000
# 24      110000
# 25       66000
# 26       80000
# 27       86000
# 28      101000
# 29       80000
# 30       61000
# 31      110000
# 32      110000
# 33       61000
# 34      101000
# 35       66000
# 36       61000
# 37      101000
# 38       86000
# 39       80000
# 40       66000
# 41       86000
# 42       80000
# 43      101000
# 44       66000
# 45      101000
# 46      101000
# 47      110000
# 48       86000
# 49      101000

# %%
final_df.info()
# As we can see, the final dataframe has the same non-null count as before!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4744 entries, 0 to 4743
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uuid                    4744 non-null   int64
#  1   name                    4744 non-null   object
#  2   dob                     4744 non-null   datetime64[ns]
#  3   sex                     4744 non-null   object
#  4   job_id                  4744 non-null   float64
#  5   num_course_taken        4744 non-null   float64
#  6   current_career_path_id  4744 non-null   float64
#  7   time_spent_hrs          4744 non-null   float64
#  8   age                     4744 non-null   int64
#  9   street                  4744 non-null   object
#  10  city                    4744 non-null   object
#  11  state                   4744 non-null   object
#  12  post_code               4744 non-null   object
#  13  email                   4744 non-null   object
#  14  career_path_id          4744 non-null   int64
#  15  career_path_name        4744 non-null   object
#  16  hours_to_complete       4744 non-null   int64
#  17  job_category            4744 non-null   object
#  18  avg_salary              4744 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(5), object(9)
# memory usage: 704.3+ KB

# %%
# Now to create the cleansed database and CSV!
final_df.to_sql('cademycode_cleaned.db', con, if_exists='replace', index=False)
final_df.to_csv('cademycode_cleaned.csv', index=False)
